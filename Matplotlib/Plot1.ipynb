# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2-D Plot
# * Used for Bivariate analysis.
# * Used for Categorial VS. Numerical.
# * used for Numerical VS. Numerical as well.

# %%
d1=pd.read_csv("D:\Python\Datasets\sharma-kohli.csv")
d1
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
# plotting single graph
plt.plot(d1["index"],d1["V Kohli"])

# %%
# plotting multiple graphs
plt.plot(d1["index"],d1["V Kohli"])
plt.plot(d1["index"],d1["RG Sharma"])

# %%
# Graph labelling
plt.plot(d1["index"],d1["V Kohli"])
plt.plot(d1["index"],d1["RG Sharma"])
plt.title("Rohit Sharma VS. Virat Kohli ipl runs comparison")
plt.xlabel("IPL Season")
plt.ylabel("Runs Scored")
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
# Colors(hex) and line(width and style) and markers
plt.plot(d1["index"],d1["V Kohli"],color="#39CCD6")
plt.plot(d1["index"],d1["RG Sharma"],color="#79210E")
plt.title("Rohit Sharma VS. Virat Kohli ipl runs comparison")
plt.xlabel("IPL Season")
plt.ylabel("Runs Scored")
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
plt.plot(d1["index"],d1["RG Sharma"],color="red",linestyle="solid",linewidth="4",marker="8",markersize="12")
plt.plot(d1["index"],d1["V Kohli"],color="#39CCD6",linestyle="dashed",linewidth="3",marker="o")

# %%
# Adding legend
plt.plot(d1["index"],d1["RG Sharma"],color="#CCD639",linestyle="solid",linewidth="3",marker="8",markersize="7",label="RG Sharma")
plt.plot(d1["index"],d1["V Kohli"],color="#39CCD6",linestyle="dotted",linewidth="3",marker="o",label="V Kohli") 
plt.legend(loc="best")

# %%
price=[48000,54000,57000,49000,47000,4500000]
year=[2017,2018,2019,2020,2021,2022]
plt.plot(year,price)

# %%
# Limiting axis
price=[48000,54000,57000,49000,47000,4500000]
year=[2017,2018,2019,2020,2021,2022]
plt.plot(year,price)
plt.ylim(0,75000)
plt.xlim(2017,2020)
# Out:
# (2017.0, 2020.0)

# %%
# Adding grids
plt.plot(d1["index"],d1["RG Sharma"],color="#CCD639",linestyle="solid",linewidth="3",marker="8",markersize="7",label="RG Sharma")
plt.plot(d1["index"],d1["V Kohli"],color="#39CCD6",linestyle="dotted",linewidth="3",marker="o",label="V Kohli") 
plt.legend(loc="best")
plt.grid()

# %% [markdown]
# # Scatter Plots
# * Used for Bivariate Analysis
# * Numerical VS. Numerical
# * Use case - Correlational Analysis

# %%
x=np.linspace(-10,10,50)
y=10*x+3+np.random.randint(0,300,50)

# To plot scatterplot
plt.scatter(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("x vs. y")
# Out:
# Text(0.5, 1.0, 'x vs. y')

# %%
d2=pd.read_csv(r"D:\Python\Datasets\batter.csv")
d2=d2.head(5)
d2
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
plt.scatter(d2["avg"],d2["strike_rate"])
plt.title("Average and Strike rate analysis of top 50 players")
plt.xlabel("Average")
plt.ylabel("Strike Rate")
# Out:
# Text(0, 0.5, 'Strike Rate')

# %%
d3=pd.read_csv(r"D:\Python\Datasets\tips.csv")
d3
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter(d3["total_bill"],d3["tip"],s=d3["size"]*10)
plt.xlabel("total_bill")
plt.ylabel("tip")
plt.title("total bill vs tip")
# Out:
# Text(0.5, 1.0, 'total bill vs tip')

# %%
# Without using scatteerrplot
# Faster
plt.plot(d3["total_bill"],d3["tip"],"o")

# %% [markdown]
# # Bar chart
# * Used for Bivariate Analysis.
# * Numerical VS. Categorical.
# * Aggregate values are taken in y-axis(Numerical)

# %%
# Simple bar chat
children=[10,20,40,10,30]
colors=["red","blue","green","yello","pink"]

# %%
plt.bar(colors,children)
plt.xlabel("colors")
plt.ylabel("children")
# Out:
# Text(0, 0.5, 'children')

# %% [markdown]
# # Horizontal bar chart
# * Used when number of categories are more

# %%
plt.barh(colors,children)
# Out:
# <BarContainer object of 5 artists>
